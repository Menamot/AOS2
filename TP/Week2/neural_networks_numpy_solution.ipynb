# %% [markdown]
# # Neural networks from scratch
#
# ## Libraries and dataset

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
from sklearn.datasets import make_moons
X, y_ = make_moons(1000, noise=.2)
y = y_[:, np.newaxis]           # Make it a one-column matrix

# %% [markdown]
# Visualize the dataset

# %%
# <answer>
plt.scatter(*X.T, c=y_)
plt.show()
# </answer>

# %% [markdown]
# ## Activation functions
#
# ReLU and sigmoid function and their derivative (should work for numpy
# array of any dimension (1D, 2D,...))

# %%
def relu(v):
    # <answer>
    vv = np.copy(v)
    vv[vv < 0] = 0
    return vv
    # </answer>


def drelu(v):
    # <answer>
    vv = np.copy(v)
    vv[vv <= 0] = 0
    vv[vv > 0] = 1
    return vv
    # </answer>


def sigmoid(v):
    # <answer>
    return 1 / (1 + np.exp(-v))
    # </answer>


def dsigmoid(v):
    # <answer>
    return sigmoid(v) * (1 - sigmoid(v))
    # </answer>

# %% [markdown]
# ## Defining the neural network
#
# First define the shape of the neural network:
#
# - `n0`: size of input,
# - `n1`: size of hidden layer,
# - `n2`: size of output.

# %%
# <answer>
n0 = 2
n1 = 50
n2 = 1
# </answer>

# %% [markdown]
# Variables for weights, biases of each layers and intermediate
# variables to compute the gradient.

# %%
# Weights
W1 = np.random.randn(n0, n1)
W2 = np.random.randn(n1, n2)

# Biases
b1 = np.random.randn(n1)
b2 = np.random.randn(n2)

# Partial derivatives of output w.r.t. activations, see slide
# "Backpropagation equations"
Xx_1 = np.zeros((n2, n1))
Xx_2 = np.zeros((n2, n2))

# Partial derivatives of output w.r.t. biases, see slide
# "Backpropagation equations"
Xb_1 = np.zeros((n2, n1))
Xb_2 = np.zeros((n2, n2))

# Partial derivatives of output w.r.t. weigths, see slide
# "Backpropagation equations"
Xw_1 = np.zeros((n2, n1, n0))
Xw_2 = np.zeros((n2, n2, n1))

# Partial derivatives of loss w.r.t. weigths and biases, see slide
# "Cross entropy loss"
Lw_1 = np.zeros((n1, n0))
Lw_2 = np.zeros((n2, n1))
Lb_1 = np.zeros(n1)
Lb_2 = np.zeros(n2)

# %% [markdown]
# Define the learning rate and the activation functions along their
# derivatives at each layer:
#
# - `eta`: learning rate
# - `af1`, `daf1`: activation function and its derivative for hidden layer
# - `af2`, `daf2`: activation function and its derivative for output layer

# %%
# Define eta, af1, daf1, af2, daf2
# <answer>
eta = 0.01
af1 = relu
daf1 = drelu
af2 = sigmoid
daf2 = dsigmoid
# </answer>

# %% [markdown]
# ## The learning loop

# %%
nepochs = 15
for epoch in range(nepochs + 1):
    for idx, (x0, y2) in enumerate(zip(X, y)):
        # Implement the forward pass: use `W1`, `x0`, `b1`, `af1`, `W2`,
        # `x1`, `b2`, `af2` to define `z1`, `x1`, `z2`, `x2`.
        # <answer>
        z1 = W1.T @ x0 + b1
        x1 = af1(z1)
        z2 = W2.T @ x1 + b2
        x2 = af2(z2)
        # </answer>

        if idx % 100 == 0:
            print(f"Epoch: {epoch}, sample: {idx}, class: {y2}, prob: {x2}")

        # To initialize the recurrent relation (3), see slide
        # "Backpropagation equations"
        # <answer>
        Xx_2 = np.eye(n2)
        # </answer>

        # Update partial derivatives of output w.r.t. weights and
        # biases on second layer
        for i in range(n2):
            for p in range(n2):
                # See equation (2) in slide "Backpropagation equations"
                # <answer>
                Xb_2[i, p] = Xx_2[i, p] * daf2(z2[p])
                # </answer>
                for q in range(n1):
                    # See equation (1) in slide "Backpropagation equations"
                    # <answer>
                    Xw_2[i, p, q] = Xx_2[i, p] * x1[q] * daf2(z2[p])
                    # </answer>

        # Update partial derivatives of output w.r.t. activations
        for i in range(n2):
            for p in range(n1):
                Xx_1[i, p] = 0
                for j in range(n2):
                    # See equation (3) in slide "Backpropagation equations"
                    # <answer>
                    Xx_1[i, p] += Xx_2[i, j] * W2[p, j] * daf2(z2[j])
                    # </answer>

        # Update partial derivatives of output w.r.t. weights and
        # biases on first layer
        for i in range(n2):
            for p in range(n1):
                # See equation (2) in slide "Backpropagation equations"
                # <answer>
                Xb_1[i, p] = Xx_1[i, p] * daf1(z1[p])
                # </answer>
                for q in range(n0):
                    # See equation (1) in slide "Backpropagation equations"
                    # <answer>
                    Xw_1[i, p, q] = Xx_1[i, p] * daf1(z1[p]) * x0[q]
                    # </answer>

        # Compute partial derivatives of the loss w.r.t weights and
        # biases. For simplicity, we will use the MSE loss instead of
        # the cross-entropy loss because it does not require an
        # additional softmax step.
        for p in range(n1):
            for q in range(n0):
                Lw_1[p, q] = 0
                for i in range(n2):
                    # Partial derivatives of loss w.r.t. weigths, see
                    # slide "MSE loss"
                    # <answer>
                    Lw_1[p, q] += 2 * (x2[i] - y2[i]) * Xw_1[i, p, q]
                    # Lw_1[p, q] += (x2[i] - y2[i]) / (x2[i] * (1 - x2[i])) * Xw_1[i, p, q]
                    # </answer>

        for p in range(n2):
            for q in range(n1):
                Lw_2[p, q] = 0
                for i in range(n2):
                    # Partial derivatives of loss w.r.t. weigths, see
                    # slide "MSE loss"
                    # <answer>
                    Lw_2[p, q] += 2 * (x2[i] - y2[i]) * Xw_2[i, p, q]
                    # Lw_2[p, q] += (x2[i] - y2[i]) / (x2[i] * (1 - x2[i])) * Xw_2[i, p, q]
                    # </answer>

        for p in range(n2):
            Lb_2[p] = 0
            for i in range(n2):
                # Partial derivatives of loss w.r.t. biases, see slide
                # "MSE loss"
                # <answer>
                Lb_2[p] += 2 * (x2[i] - y2[i]) * Xb_2[i, p]
                # Lb_2[p] += (x2[i] - y2[i]) / (x2[i] * (1 - x2[i])) * Xb_2[i, p]
                # </answer>

        for p in range(n1):
            Lb_1[p] = 0
            for i in range(n2):
                # Partial derivatives of loss w.r.t. biases, see slide
                # "MSE loss"
                # <answer>
                Lb_1[p] += 2 * (x2[i] - y2[i]) * Xb_1[i, p]
                # Lb_1[p] += (x2[i] - y2[i]) / (x2[i] * (1 - x2[i])) * Xb_1[i, p]
                # </answer>

        # Gradient descent step: use `eta`, `Lw_1` `Lw_2` `Lb_1` `Lb_2` to
        # update `W1`, `W2`, `b1`, `b2`.
        # <answer>
        W1 -= eta * Lw_1.T
        W2 -= eta * Lw_2.T
        b1 -= eta * Lb_1
        b2 -= eta * Lb_2
        # </answer>
# Out:
# Epoch: 0, sample: 0, class: [1], prob: [0.64944547]
# Epoch: 0, sample: 100, class: [1], prob: [0.96579379]
# Epoch: 0, sample: 200, class: [0], prob: [0.35961754]
# Epoch: 0, sample: 300, class: [0], prob: [0.25024406]
# Epoch: 0, sample: 400, class: [1], prob: [0.95570838]
# Epoch: 0, sample: 500, class: [1], prob: [0.18329333]
# Epoch: 0, sample: 600, class: [0], prob: [0.0019922]
# Epoch: 0, sample: 700, class: [0], prob: [0.67548625]
# Epoch: 0, sample: 800, class: [0], prob: [0.33074299]
# Epoch: 0, sample: 900, class: [1], prob: [0.98096762]
# Epoch: 1, sample: 0, class: [1], prob: [0.93520768]
# Epoch: 1, sample: 100, class: [1], prob: [0.98886354]
# Epoch: 1, sample: 200, class: [0], prob: [0.49974634]
# Epoch: 1, sample: 300, class: [0], prob: [0.17477888]
# Epoch: 1, sample: 400, class: [1], prob: [0.94701026]
# Epoch: 1, sample: 500, class: [1], prob: [0.67834006]
# Epoch: 1, sample: 600, class: [0], prob: [0.03135838]
# Epoch: 1, sample: 700, class: [0], prob: [0.56873403]
# Epoch: 1, sample: 800, class: [0], prob: [0.20598815]
# Epoch: 1, sample: 900, class: [1], prob: [0.97223674]
# Epoch: 2, sample: 0, class: [1], prob: [0.92774603]
# Epoch: 2, sample: 100, class: [1], prob: [0.98663971]
# Epoch: 2, sample: 200, class: [0], prob: [0.36971644]
# Epoch: 2, sample: 300, class: [0], prob: [0.12286921]
# Epoch: 2, sample: 400, class: [1], prob: [0.95825502]
# Epoch: 2, sample: 500, class: [1], prob: [0.75140877]
# Epoch: 2, sample: 600, class: [0], prob: [0.04981016]
# Epoch: 2, sample: 700, class: [0], prob: [0.52554242]
# Epoch: 2, sample: 800, class: [0], prob: [0.17599562]
# Epoch: 2, sample: 900, class: [1], prob: [0.96536832]
# Epoch: 3, sample: 0, class: [1], prob: [0.93708366]
# Epoch: 3, sample: 100, class: [1], prob: [0.98303042]
# Epoch: 3, sample: 200, class: [0], prob: [0.28948738]
# Epoch: 3, sample: 300, class: [0], prob: [0.09989615]
# Epoch: 3, sample: 400, class: [1], prob: [0.96722542]
# Epoch: 3, sample: 500, class: [1], prob: [0.78671303]
# Epoch: 3, sample: 600, class: [0], prob: [0.05135815]
# Epoch: 3, sample: 700, class: [0], prob: [0.50254576]
# Epoch: 3, sample: 800, class: [0], prob: [0.15585421]
# Epoch: 3, sample: 900, class: [1], prob: [0.96237271]
# Epoch: 4, sample: 0, class: [1], prob: [0.94308009]
# Epoch: 4, sample: 100, class: [1], prob: [0.98093746]
# Epoch: 4, sample: 200, class: [0], prob: [0.24716985]
# Epoch: 4, sample: 300, class: [0], prob: [0.0866269]
# Epoch: 4, sample: 400, class: [1], prob: [0.97268954]
# Epoch: 4, sample: 500, class: [1], prob: [0.81479219]
# Epoch: 4, sample: 600, class: [0], prob: [0.0474754]
# Epoch: 4, sample: 700, class: [0], prob: [0.48124635]
# Epoch: 4, sample: 800, class: [0], prob: [0.13739324]
# Epoch: 4, sample: 900, class: [1], prob: [0.95972405]
# Epoch: 5, sample: 0, class: [1], prob: [0.94793955]
# Epoch: 5, sample: 100, class: [1], prob: [0.98010016]
# Epoch: 5, sample: 200, class: [0], prob: [0.23234476]
# Epoch: 5, sample: 300, class: [0], prob: [0.07556912]
# Epoch: 5, sample: 400, class: [1], prob: [0.97647443]
# Epoch: 5, sample: 500, class: [1], prob: [0.83788502]
# Epoch: 5, sample: 600, class: [0], prob: [0.04250102]
# Epoch: 5, sample: 700, class: [0], prob: [0.46100369]
# Epoch: 5, sample: 800, class: [0], prob: [0.1219392]
# Epoch: 5, sample: 900, class: [1], prob: [0.95722509]
# Epoch: 6, sample: 0, class: [1], prob: [0.95175881]
# Epoch: 6, sample: 100, class: [1], prob: [0.9799201]
# Epoch: 6, sample: 200, class: [0], prob: [0.23555]
# Epoch: 6, sample: 300, class: [0], prob: [0.06763401]
# Epoch: 6, sample: 400, class: [1], prob: [0.97917383]
# Epoch: 6, sample: 500, class: [1], prob: [0.85576621]
# Epoch: 6, sample: 600, class: [0], prob: [0.03846214]
# Epoch: 6, sample: 700, class: [0], prob: [0.44462083]
# Epoch: 6, sample: 800, class: [0], prob: [0.10996004]
# Epoch: 6, sample: 900, class: [1], prob: [0.95560103]
# Epoch: 7, sample: 0, class: [1], prob: [0.95514907]
# Epoch: 7, sample: 100, class: [1], prob: [0.98023113]
# Epoch: 7, sample: 200, class: [0], prob: [0.23837724]
# Epoch: 7, sample: 300, class: [0], prob: [0.0623519]
# Epoch: 7, sample: 400, class: [1], prob: [0.98153731]
# Epoch: 7, sample: 500, class: [1], prob: [0.86804098]
# Epoch: 7, sample: 600, class: [0], prob: [0.03548795]
# Epoch: 7, sample: 700, class: [0], prob: [0.43635292]
# Epoch: 7, sample: 800, class: [0], prob: [0.1018244]
# Epoch: 7, sample: 900, class: [1], prob: [0.95472711]
# Epoch: 8, sample: 0, class: [1], prob: [0.95810688]
# Epoch: 8, sample: 100, class: [1], prob: [0.98059339]
# Epoch: 8, sample: 200, class: [0], prob: [0.2386661]
# Epoch: 8, sample: 300, class: [0], prob: [0.05807105]
# Epoch: 8, sample: 400, class: [1], prob: [0.98332763]
# Epoch: 8, sample: 500, class: [1], prob: [0.87753462]
# Epoch: 8, sample: 600, class: [0], prob: [0.03319512]
# Epoch: 8, sample: 700, class: [0], prob: [0.42930565]
# Epoch: 8, sample: 800, class: [0], prob: [0.09374884]
# Epoch: 8, sample: 900, class: [1], prob: [0.95413457]
# Epoch: 9, sample: 0, class: [1], prob: [0.96064328]
# Epoch: 9, sample: 100, class: [1], prob: [0.98080775]
# Epoch: 9, sample: 200, class: [0], prob: [0.24199287]
# Epoch: 9, sample: 300, class: [0], prob: [0.05360837]
# Epoch: 9, sample: 400, class: [1], prob: [0.98493507]
# Epoch: 9, sample: 500, class: [1], prob: [0.8865271]
# Epoch: 9, sample: 600, class: [0], prob: [0.03103584]
# Epoch: 9, sample: 700, class: [0], prob: [0.42400245]
# Epoch: 9, sample: 800, class: [0], prob: [0.08718084]
# Epoch: 9, sample: 900, class: [1], prob: [0.95531252]
# Epoch: 10, sample: 0, class: [1], prob: [0.96321377]
# Epoch: 10, sample: 100, class: [1], prob: [0.98122516]
# Epoch: 10, sample: 200, class: [0], prob: [0.24375341]
# Epoch: 10, sample: 300, class: [0], prob: [0.05000152]
# Epoch: 10, sample: 400, class: [1], prob: [0.98615374]
# Epoch: 10, sample: 500, class: [1], prob: [0.89383868]
# Epoch: 10, sample: 600, class: [0], prob: [0.02910785]
# Epoch: 10, sample: 700, class: [0], prob: [0.41921341]
# Epoch: 10, sample: 800, class: [0], prob: [0.08185229]
# Epoch: 10, sample: 900, class: [1], prob: [0.95608794]
# Epoch: 11, sample: 0, class: [1], prob: [0.96529636]
# Epoch: 11, sample: 100, class: [1], prob: [0.98171914]
# Epoch: 11, sample: 200, class: [0], prob: [0.24550978]
# Epoch: 11, sample: 300, class: [0], prob: [0.04700287]
# Epoch: 11, sample: 400, class: [1], prob: [0.98715854]
# Epoch: 11, sample: 500, class: [1], prob: [0.90035939]
# Epoch: 11, sample: 600, class: [0], prob: [0.02744836]
# Epoch: 11, sample: 700, class: [0], prob: [0.41589788]
# Epoch: 11, sample: 800, class: [0], prob: [0.07634533]
# Epoch: 11, sample: 900, class: [1], prob: [0.95611783]
# Epoch: 12, sample: 0, class: [1], prob: [0.96671242]
# Epoch: 12, sample: 100, class: [1], prob: [0.9823285]
# Epoch: 12, sample: 200, class: [0], prob: [0.24894854]
# Epoch: 12, sample: 300, class: [0], prob: [0.04439832]
# Epoch: 12, sample: 400, class: [1], prob: [0.98787499]
# Epoch: 12, sample: 500, class: [1], prob: [0.90619165]
# Epoch: 12, sample: 600, class: [0], prob: [0.02591301]
# Epoch: 12, sample: 700, class: [0], prob: [0.41264151]
# Epoch: 12, sample: 800, class: [0], prob: [0.07244454]
# Epoch: 12, sample: 900, class: [1], prob: [0.95646042]
# Epoch: 13, sample: 0, class: [1], prob: [0.96809698]
# Epoch: 13, sample: 100, class: [1], prob: [0.98296913]
# Epoch: 13, sample: 200, class: [0], prob: [0.25132833]
# Epoch: 13, sample: 300, class: [0], prob: [0.04215383]
# Epoch: 13, sample: 400, class: [1], prob: [0.98865244]
# Epoch: 13, sample: 500, class: [1], prob: [0.91125336]
# Epoch: 13, sample: 600, class: [0], prob: [0.02468786]
# Epoch: 13, sample: 700, class: [0], prob: [0.41001482]
# Epoch: 13, sample: 800, class: [0], prob: [0.06901854]
# Epoch: 13, sample: 900, class: [1], prob: [0.95712174]
# Epoch: 14, sample: 0, class: [1], prob: [0.96930901]
# Epoch: 14, sample: 100, class: [1], prob: [0.98348197]
# Epoch: 14, sample: 200, class: [0], prob: [0.25368517]
# Epoch: 14, sample: 300, class: [0], prob: [0.04022843]
# Epoch: 14, sample: 400, class: [1], prob: [0.98929815]
# Epoch: 14, sample: 500, class: [1], prob: [0.91575868]
# Epoch: 14, sample: 600, class: [0], prob: [0.02359299]
# Epoch: 14, sample: 700, class: [0], prob: [0.40419125]
# Epoch: 14, sample: 800, class: [0], prob: [0.065645]
# Epoch: 14, sample: 900, class: [1], prob: [0.95728936]
# Epoch: 15, sample: 0, class: [1], prob: [0.97020493]
# Epoch: 15, sample: 100, class: [1], prob: [0.98395322]
# Epoch: 15, sample: 200, class: [0], prob: [0.25555353]
# Epoch: 15, sample: 300, class: [0], prob: [0.03803444]
# Epoch: 15, sample: 400, class: [1], prob: [0.98994394]
# Epoch: 15, sample: 500, class: [1], prob: [0.91982227]
# Epoch: 15, sample: 600, class: [0], prob: [0.02264579]
# Epoch: 15, sample: 700, class: [0], prob: [0.40184007]
# Epoch: 15, sample: 800, class: [0], prob: [0.06272616]
# Epoch: 15, sample: 900, class: [1], prob: [0.95808406]

# %% [markdown]
# ## Vizualization

# %%
# num = 250
# x = np.linspace(X[:, 0].min(), X[:, 0].max(), num)
# y = np.linspace(X[:, 1].min(), X[:, 1].max(), num)
# XX, YY = np.meshgrid(x, y)
# points = np.c_[XX.ravel(), YY.ravel()]
# 
# z1 = W1.T @ points.T + b1[:, np.newaxis]
# x1 = af1(z1)
# z2 = W2.T @ x1 + b2[:, np.newaxis]
# x2 = af2(z2)
# 
# C = x2.reshape(num, num)
# 
# plt.contourf(XX, YY, C, cmap=plt.cm.RdBu, alpha=.5)
# cm_bright = ListedColormap(['#FF0000', '#0000FF'])
# plt.scatter(*X.T, c=y_, cmap=cm_bright)
# 
# plt.show()

# %%
b2
# Out:
# array([-2.35941844])

# %%
z1=X@W1 + b1
x1=sigmoid(z1)
z2=x1@W2+b2
ypr=sigmoid(z2)
ypr
# Out:
# array([[0.83528385],
#        [0.61892402],
#        [0.91716644],
#        [0.79839593],
#        [0.83213942],
#        [0.8293133 ],
#        [0.68174152],
#        [0.10677239],
#        [0.4373573 ],
#        [0.55315942],
#        [0.65088773],
#        [0.86295133],
#        [0.31258894],
#        [0.01404699],
#        [0.11074952],
#        [0.01376341],
#        [0.82509519],
#        [0.81644631],
#        [0.86696991],
#        [0.01665499],
#        [0.01360126],
#        [0.8411872 ],
#        [0.5640707 ],
#        [0.13723999],
#        [0.01235672],
#        [0.04737844],
#        [0.78601876],
#        [0.2586297 ],
#        [0.01288909],
#        [0.46818987],
#        [0.01681578],
#        [0.83102131],
#        [0.02043723],
#        [0.33268766],
#        [0.37524204],
#        [0.80261263],
#        [0.08334588],
#        [0.84288007],
#        [0.0149929 ],
#        [0.08393498],
#        [0.29920371],
#        [0.02183095],
#        [0.79405642],
#        [0.76210608],
#        [0.08630817],
#        [0.01319585],
#        [0.83660194],
#        [0.81041454],
#        [0.25347336],
#        [0.86537631],
#        [0.79016709],
#        [0.63958119],
#        [0.00846017],
#        [0.38510355],
#        [0.65530382],
#        [0.01064712],
#        [0.0528536 ],
#        [0.79933276],
#        [0.07685493],
#        [0.05739577],
#        [0.85801379],
#        [0.83455755],
#        [0.73833979],
#        [0.04140931],
#        [0.80148609],
#        [0.32514066],
#        [0.45136666],
#        [0.0646633 ],
#        [0.83403712],
#        [0.02731142],
#        [0.04298223],
#        [0.01137459],
#        [0.06860647],
#        [0.08584816],
#        [0.02824817],
#        [0.58675544],
#        [0.49508086],
#        [0.42727064],
#        [0.78844789],
#        [0.66522392],
#        [0.42230303],
#        [0.49595485],
#        [0.03738729],
#        [0.24809704],
#        [0.01591076],
#        [0.48986291],
#        [0.78409471],
#        [0.82295289],
#        [0.16422499],
#        [0.56612441],
#        [0.01053624],
#        [0.02712921],
#        [0.14427284],
#        [0.71404967],
#        [0.22898595],
#        [0.72574553],
#        [0.00979552],
#        [0.00770021],
#        [0.83659209],
#        [0.02052768],
#        [0.67435654],
#        [0.11859161],
#        [0.770963  ],
#        [0.81269654],
#        [0.00802281],
#        [0.81335087],
#        [0.17920635],
#        [0.85465782],
#        [0.38866889],
#        [0.04307062],
#        [0.81215182],
#        [0.78469551],
#        [0.81323965],
#        [0.82898266],
#        [0.01836196],
#        [0.50017366],
#        [0.75425764],
#        [0.87624062],
#        [0.45011614],
#        [0.07795469],
#        [0.78751491],
#        [0.81307541],
#        [0.42341929],
#        [0.61689998],
#        [0.05518014],
#        [0.64834173],
#        [0.80804253],
#        [0.39180491],
#        [0.8263096 ],
#        [0.54073051],
#        [0.38149523],
#        [0.54864097],
#        [0.05118555],
#        [0.56969402],
#        [0.01273315],
#        [0.01717574],
#        [0.23297825],
#        [0.84175549],
#        [0.17761199],
#        [0.8285307 ],
#        [0.73304751],
#        [0.44172776],
#        [0.01102894],
#        [0.66000515],
#        [0.34079013],
#        [0.03535339],
#        [0.86331042],
#        [0.82663148],
#        [0.03185478],
#        [0.06404151],
#        [0.76300674],
#        [0.74368375],
#        [0.00973152],
#        [0.02874051],
#        [0.14075459],
#        [0.7072859 ],
#        [0.1039856 ],
#        [0.02257524],
#        [0.66086218],
#        [0.86520402],
#        [0.65933338],
#        [0.36204229],
#        [0.10013612],
#        [0.01098094],
#        [0.01167662],
#        [0.00869958],
#        [0.67074467],
#        [0.03569158],
#        [0.8537785 ],
#        [0.11204262],
#        [0.85821796],
#        [0.80426057],
#        [0.84720759],
#        [0.01737828],
#        [0.73090673],
#        [0.76455269],
#        [0.6713267 ],
#        [0.81978243],
#        [0.11243191],
#        [0.0101179 ],
#        [0.78939359],
#        [0.2726114 ],
#        [0.41004062],
#        [0.01273289],
#        [0.87275951],
#        [0.89046631],
#        [0.0103755 ],
#        [0.85982736],
#        [0.74030391],
#        [0.74233808],
#        [0.03653836],
#        [0.71621855],
#        [0.72356946],
#        [0.04231706],
#        [0.88249311],
#        [0.7701605 ],
#        [0.08713173],
#        [0.03626254],
#        [0.75322942],
#        [0.42587227],
#        [0.30241083],
#        [0.85319063],
#        [0.73471908],
#        [0.01891886],
#        [0.74937629],
#        [0.02111055],
#        [0.01381943],
#        [0.84953838],
#        [0.8998705 ],
#        [0.81307566],
#        [0.02470295],
#        [0.49690577],
#        [0.01558757],
#        [0.84876981],
#        [0.06999128],
#        [0.01756283],
#        [0.04725357],
#        [0.83114464],
#        [0.11059554],
#        [0.83419315],
#        [0.8475638 ],
#        [0.01116274],
#        [0.02072767],
#        [0.62728004],
#        [0.46917143],
#        [0.0511712 ],
#        [0.01210914],
#        [0.00870083],
#        [0.84712329],
#        [0.77762894],
#        [0.00901231],
#        [0.81861762],
#        [0.0281688 ],
#        [0.78471044],
#        [0.41037545],
#        [0.61051846],
#        [0.51223878],
#        [0.8578685 ],
#        [0.8261438 ],
#        [0.36549172],
#        [0.84430354],
#        [0.31799922],
#        [0.01007383],
#        [0.08718926],
#        [0.8639497 ],
#        [0.5213283 ],
#        [0.01581414],
#        [0.01963014],
#        [0.80769052],
#        [0.03881457],
#        [0.02273605],
#        [0.05364138],
#        [0.01789905],
#        [0.86927351],
#        [0.226231  ],
#        [0.76054022],
#        [0.81507682],
#        [0.81730945],
#        [0.2462511 ],
#        [0.45020717],
#        [0.04520448],
#        [0.74520177],
#        [0.04141045],
#        [0.51439211],
#        [0.71568053],
#        [0.13341929],
#        [0.59929813],
#        [0.08075868],
#        [0.82280168],
#        [0.75865674],
#        [0.37247571],
#        [0.02673382],
#        [0.04998258],
#        [0.79430937],
#        [0.00930973],
#        [0.01433545],
#        [0.80318944],
#        [0.01028424],
#        [0.27089332],
#        [0.79001198],
#        [0.06206382],
#        [0.27734991],
#        [0.70223758],
#        [0.01962747],
#        [0.61638489],
#        [0.80231894],
#        [0.84151685],
#        [0.782329  ],
#        [0.04542693],
#        [0.02139687],
#        [0.0304764 ],
#        [0.30350617],
#        [0.61303606],
#        [0.85695287],
#        [0.03792287],
#        [0.49700452],
#        [0.22032576],
#        [0.01475217],
#        [0.21017827],
#        [0.01486465],
#        [0.41005915],
#        [0.70719797],
#        [0.02351531],
#        [0.02574931],
#        [0.79097957],
#        [0.80445251],
#        [0.19198923],
#        [0.04324072],
#        [0.05264934],
#        [0.04617933],
#        [0.0104965 ],
#        [0.42079151],
#        [0.03336943],
#        [0.21176187],
#        [0.83217621],
#        [0.70252737],
#        [0.2792066 ],
#        [0.0403984 ],
#        [0.40997745],
#        [0.05545882],
#        [0.0775555 ],
#        [0.81344685],
#        [0.00741738],
#        [0.15079125],
#        [0.01107361],
#        [0.0086094 ],
#        [0.02840729],
#        [0.85600741],
#        [0.46903614],
#        [0.01509042],
#        [0.56193211],
#        [0.68204494],
#        [0.15187201],
#        [0.70370173],
#        [0.0265944 ],
#        [0.01795458],
#        [0.83371378],
#        [0.50262554],
#        [0.03025858],
#        [0.0415369 ],
#        [0.15664211],
#        [0.02246239],
#        [0.61406026],
#        [0.56617773],
#        [0.84573436],
#        [0.05134757],
#        [0.02156589],
#        [0.07444968],
#        [0.00889267],
#        [0.63650085],
#        [0.17549215],
#        [0.67711311],
#        [0.86859888],
#        [0.84220636],
#        [0.01097004],
#        [0.76931631],
#        [0.14167177],
#        [0.86311863],
#        [0.35167606],
#        [0.7729608 ],
#        [0.33713327],
#        [0.31002056],
#        [0.29505954],
#        [0.58636878],
#        [0.03005958],
#        [0.90009451],
#        [0.04303947],
#        [0.83650146],
#        [0.01410998],
#        [0.02043152],
#        [0.85506985],
#        [0.14796076],
#        [0.03427999],
#        [0.01487946],
#        [0.37456843],
#        [0.67920742],
#        [0.32544333],
#        [0.2139877 ],
#        [0.71857714],
#        [0.61601166],
#        [0.01378148],
#        [0.85136892],
#        [0.30939352],
#        [0.70818842],
#        [0.59156101],
#        [0.88463256],
#        [0.37954591],
#        [0.82663121],
#        [0.45194807],
#        [0.01317557],
#        [0.00891487],
#        [0.68779405],
#        [0.13246766],
#        [0.17951658],
#        [0.61385477],
#        [0.61221415],
#        [0.0901855 ],
#        [0.00944016],
#        [0.13256437],
#        [0.82665107],
#        [0.84971152],
#        [0.14008475],
#        [0.06163257],
#        [0.29513219],
#        [0.86368558],
#        [0.7856916 ],
#        [0.021805  ],
#        [0.01337586],
#        [0.03549774],
#        [0.86613805],
#        [0.01821899],
#        [0.12988879],
#        [0.01623175],
#        [0.01852928],
#        [0.47633488],
#        [0.08397876],
#        [0.308603  ],
#        [0.08172944],
#        [0.4114526 ],
#        [0.86300669],
#        [0.01022333],
#        [0.22747252],
#        [0.01906746],
#        [0.07942878],
#        [0.79917783],
#        [0.01323117],
#        [0.35855387],
#        [0.02595341],
#        [0.01352479],
#        [0.01224913],
#        [0.54662353],
#        [0.59461714],
#        [0.1504615 ],
#        [0.0135619 ],
#        [0.01848639],
#        [0.59687651],
#        [0.01169614],
#        [0.12766871],
#        [0.86500353],
#        [0.10965498],
#        [0.1019768 ],
#        [0.01718736],
#        [0.74212726],
#        [0.4441426 ],
#        [0.79572315],
#        [0.83113964],
#        [0.84338746],
#        [0.18948007],
#        [0.67347676],
#        [0.31311023],
#        [0.03824853],
#        [0.83415656],
#        [0.85508313],
#        [0.78649775],
#        [0.01739716],
#        [0.46312172],
#        [0.01114496],
#        [0.57000365],
#        [0.8744658 ],
#        [0.84941756],
#        [0.00819855],
#        [0.87277667],
#        [0.20595117],
#        [0.72411302],
#        [0.54366547],
#        [0.77324401],
#        [0.76661924],
#        [0.11605685],
#        [0.00550961],
#        [0.86687038],
#        [0.81471656],
#        [0.00975659],
#        [0.77507614],
#        [0.01757161],
#        [0.01592966],
#        [0.03640653],
#        [0.88361641],
#        [0.61470485],
#        [0.00720412],
#        [0.01192998],
#        [0.62132938],
#        [0.65949745],
#        [0.01572404],
#        [0.02489011],
#        [0.51526832],
#        [0.62696336],
#        [0.0124214 ],
#        [0.85870995],
#        [0.79939307],
#        [0.84883792],
#        [0.01398823],
#        [0.47942627],
#        [0.01244164],
#        [0.6396701 ],
#        [0.00946297],
#        [0.81042038],
#        [0.59696112],
#        [0.80366286],
#        [0.00774069],
#        [0.04846605],
#        [0.07960471],
#        [0.39347205],
#        [0.82167504],
#        [0.01418441],
#        [0.48672899],
#        [0.15944242],
#        [0.0159137 ],
#        [0.05787414],
#        [0.8382247 ],
#        [0.27148308],
#        [0.01743041],
#        [0.01492149],
#        [0.62952689],
#        [0.09270984],
#        [0.11649235],
#        [0.45661746],
#        [0.01357299],
#        [0.04241375],
#        [0.3988185 ],
#        [0.01286136],
#        [0.00971964],
#        [0.7550091 ],
#        [0.00823327],
#        [0.7712093 ],
#        [0.13848329],
#        [0.3635779 ],
#        [0.84540204],
#        [0.00791297],
#        [0.02121616],
#        [0.05718818],
#        [0.01147191],
#        [0.05580619],
#        [0.82829672],
#        [0.87029879],
#        [0.81642526],
#        [0.04464186],
#        [0.81944039],
#        [0.76101974],
#        [0.85950567],
#        [0.76384266],
#        [0.7961997 ],
#        [0.01584209],
#        [0.01920888],
#        [0.00711424],
#        [0.11708599],
#        [0.01256709],
#        [0.33773354],
#        [0.51090146],
#        [0.00819712],
#        [0.78409056],
#        [0.78800963],
#        [0.53398898],
#        [0.79812559],
#        [0.82878373],
#        [0.16142301],
#        [0.0550827 ],
#        [0.01520874],
#        [0.82010628],
#        [0.78615584],
#        [0.74414008],
#        [0.00990059],
#        [0.01359241],
#        [0.63462214],
#        [0.78736436],
#        [0.86056794],
#        [0.02195769],
#        [0.03770926],
#        [0.74771234],
#        [0.20476941],
#        [0.01268621],
#        [0.45099101],
#        [0.01321747],
#        [0.8428081 ],
#        [0.54501949],
#        [0.034101  ],
#        [0.04909526],
#        [0.02403601],
#        [0.00856128],
#        [0.52009432],
#        [0.65106196],
#        [0.83011687],
#        [0.85445174],
#        [0.02033178],
#        [0.76419232],
#        [0.7938396 ],
#        [0.06823427],
#        [0.00706136],
#        [0.00641569],
#        [0.01604252],
#        [0.01951882],
#        [0.54891246],
#        [0.07419315],
#        [0.3760946 ],
#        [0.80271602],
#        [0.01409844],
#        [0.01064365],
#        [0.81868411],
#        [0.02117972],
#        [0.59582392],
#        [0.24237322],
#        [0.01213528],
#        [0.44964268],
#        [0.09544549],
#        [0.05294912],
#        [0.80770261],
#        [0.83086928],
#        [0.00689254],
#        [0.02155803],
#        [0.77563598],
#        [0.51983052],
#        [0.01831778],
#        [0.05415548],
#        [0.02348638],
#        [0.01816208],
#        [0.03606102],
#        [0.79110927],
#        [0.01244567],
#        [0.69643123],
#        [0.77503809],
#        [0.01155994],
#        [0.81868599],
#        [0.09595376],
#        [0.7010208 ],
#        [0.03374616],
#        [0.86426914],
#        [0.81363537],
#        [0.0306304 ],
#        [0.01027688],
#        [0.0088732 ],
#        [0.01684955],
#        [0.71950159],
#        [0.78871704],
#        [0.02139465],
#        [0.85791539],
#        [0.00893366],
#        [0.84470255],
#        [0.23651788],
#        [0.13156074],
#        [0.01191202],
#        [0.09489692],
#        [0.85590976],
#        [0.3726429 ],
#        [0.12850443],
#        [0.2911438 ],
#        [0.78734194],
#        [0.72294754],
#        [0.01451739],
#        [0.68569107],
#        [0.00956083],
#        [0.01173243],
#        [0.01785151],
#        [0.02190769],
#        [0.00920894],
#        [0.58497924],
#        [0.01346391],
#        [0.1081036 ],
#        [0.06811057],
#        [0.83642961],
#        [0.1514221 ],
#        [0.02145999],
#        [0.11028383],
#        [0.02068371],
#        [0.01724898],
#        [0.04878747],
#        [0.85107271],
#        [0.65348271],
#        [0.35325671],
#        [0.13166242],
#        [0.75044618],
#        [0.06740347],
#        [0.80972963],
#        [0.02276983],
#        [0.84074161],
#        [0.84221707],
#        [0.69080888],
#        [0.00984133],
#        [0.17817122],
#        [0.82992461],
#        [0.90123905],
#        [0.07769707],
#        [0.77412107],
#        [0.00684014],
#        [0.43851586],
#        [0.31763097],
#        [0.71667454],
#        [0.82904681],
#        [0.11585074],
#        [0.00707901],
#        [0.01408556],
#        [0.84169625],
#        [0.82773156],
#        [0.00916193],
#        [0.08930381],
#        [0.00836845],
#        [0.01299835],
#        [0.82789242],
#        [0.80674864],
#        [0.86669548],
#        [0.07096672],
#        [0.79230581],
#        [0.66487252],
#        [0.10095297],
#        [0.01349116],
#        [0.20487217],
#        [0.74318237],
#        [0.2652854 ],
#        [0.04886587],
#        [0.82568952],
#        [0.7314521 ],
#        [0.76318376],
#        [0.831821  ],
#        [0.82771076],
#        [0.00946629],
#        [0.03353946],
#        [0.30846516],
#        [0.01997457],
#        [0.09222808],
#        [0.81234602],
#        [0.01628611],
#        [0.80154265],
#        [0.81377507],
#        [0.02763601],
#        [0.1382133 ],
#        [0.36946628],
#        [0.00734391],
#        [0.23585521],
#        [0.85274799],
#        [0.16649501],
#        [0.85488539],
#        [0.82299021],
#        [0.03958301],
#        [0.01401067],
#        [0.83924945],
#        [0.01387559],
#        [0.01024462],
#        [0.10620606],
#        [0.01245066],
#        [0.01973866],
#        [0.71782339],
#        [0.02774633],
#        [0.85370358],
#        [0.68213695],
#        [0.47947812],
#        [0.09488904],
#        [0.01298619],
#        [0.72573207],
#        [0.32543724],
#        [0.0155456 ],
#        [0.85930342],
#        [0.84528431],
#        [0.0257652 ],
#        [0.23338177],
#        [0.41609712],
#        [0.2128425 ],
#        [0.02375347],
#        [0.25482733],
#        [0.82358673],
#        [0.02340644],
#        [0.50419844],
#        [0.8041058 ],
#        [0.02978755],
#        [0.52900076],
#        [0.14704004],
#        [0.03522103],
#        [0.44054634],
#        [0.11238881],
#        [0.25990234],
#        [0.07629332],
#        [0.06247085],
#        [0.82509052],
#        [0.08901953],
#        [0.81334741],
#        [0.63660772],
#        [0.0082837 ],
#        [0.71188539],
#        [0.08542945],
#        [0.60083502],
#        [0.56981039],
#        [0.76804491],
#        [0.82924121],
#        [0.02849151],
#        [0.17244056],
#        [0.2238296 ],
#        [0.32163984],
#        [0.74898734],
#        [0.10856548],
#        [0.25805675],
#        [0.08386566],
#        [0.7639645 ],
#        [0.04633502],
#        [0.0279555 ],
#        [0.35282149],
#        [0.18575177],
#        [0.55327701],
#        [0.72739006],
#        [0.03418189],
#        [0.87951563],
#        [0.01031036],
#        [0.80958019],
#        [0.28564397],
#        [0.481902  ],
#        [0.20536051],
#        [0.01385353],
#        [0.77990228],
#        [0.801811  ],
#        [0.0346589 ],
#        [0.1332629 ],
#        [0.11425466],
#        [0.00951731],
#        [0.42267088],
#        [0.01011853],
#        [0.75713783],
#        [0.14382715],
#        [0.21481183],
#        [0.51561818],
#        [0.33919046],
#        [0.00867821],
#        [0.06653288],
#        [0.72606935],
#        [0.22058171],
#        [0.00824525],
#        [0.04199775],
#        [0.03018205],
#        [0.67334921],
#        [0.82030523],
#        [0.71963463],
#        [0.00922301],
#        [0.12941019],
#        [0.85000709],
#        [0.19387148],
#        [0.01285381],
#        [0.2308374 ],
#        [0.006381  ],
#        [0.86617694],
#        [0.61984186],
#        [0.15278818],
#        [0.02346853],
#        [0.02574172],
#        [0.02196839],
#        [0.84995527],
#        [0.0261308 ],
#        [0.20210695],
#        [0.00855141],
#        [0.01157008],
#        [0.0333836 ],
#        [0.78574577],
#        [0.45776689],
#        [0.79067287],
#        [0.82362819],
#        [0.46874548],
#        [0.00951025],
#        [0.52561098],
#        [0.02947729],
#        [0.86455381],
#        [0.55572831],
#        [0.00960683],
#        [0.18478908],
#        [0.86893713],
#        [0.79173794],
#        [0.14215493],
#        [0.5148629 ],
#        [0.69503083],
#        [0.76739923],
#        [0.52251962],
#        [0.83660306],
#        [0.00683078],
#        [0.01306582],
#        [0.76277374],
#        [0.76124222],
#        [0.83155077],
#        [0.49505394],
#        [0.00694244],
#        [0.02322005],
#        [0.80748568],
#        [0.02845381],
#        [0.2049863 ],
#        [0.17355984],
#        [0.00934628],
#        [0.49955096],
#        [0.24535983],
#        [0.02690788],
#        [0.10358432],
#        [0.83749414],
#        [0.35927033],
#        [0.72155944],
#        [0.8128125 ],
#        [0.82514504],
#        [0.49521025],
#        [0.37475069],
#        [0.14102806],
#        [0.01534666],
#        [0.00829918],
#        [0.8570998 ],
#        [0.00885364],
#        [0.18858286],
#        [0.01087048],
#        [0.37255557],
#        [0.0443484 ],
#        [0.18006429],
#        [0.28888381],
#        [0.83486442],
#        [0.8105982 ],
#        [0.00822294],
#        [0.05433557],
#        [0.02012656],
#        [0.38032291],
#        [0.24294107],
#        [0.0383935 ],
#        [0.05756743],
#        [0.85346905],
#        [0.00796902],
#        [0.55291245],
#        [0.81404797],
#        [0.61290827],
#        [0.80974635],
#        [0.0334675 ],
#        [0.79998372],
#        [0.74201864],
#        [0.13872873],
#        [0.01834542],
#        [0.01357004],
#        [0.85934926],
#        [0.02734812],
#        [0.66317115],
#        [0.81076555],
#        [0.52712091],
#        [0.83251106],
#        [0.01496052],
#        [0.02258096],
#        [0.02224487],
#        [0.79351906],
#        [0.03181153],
#        [0.76963392],
#        [0.01482458],
#        [0.83739071],
#        [0.64930021],
#        [0.84205329],
#        [0.8083618 ],
#        [0.85210961],
#        [0.83600535],
#        [0.86348349],
#        [0.02682813],
#        [0.63820316],
#        [0.81815448],
#        [0.82858538],
#        [0.02825633],
#        [0.80890126],
#        [0.74175375],
#        [0.84883119],
#        [0.07828531],
#        [0.01153004],
#        [0.16711583],
#        [0.50632332],
#        [0.19659799],
#        [0.01462925],
#        [0.80691633],
#        [0.02284352],
#        [0.308064  ],
#        [0.83806542],
#        [0.14306577],
#        [0.82120613],
#        [0.66182763],
#        [0.01669067],
#        [0.01274666],
#        [0.21282761],
#        [0.0129048 ],
#        [0.28814306],
#        [0.03082394],
#        [0.01506363],
#        [0.17427048],
#        [0.84531999],
#        [0.80913789],
#        [0.07758065],
#        [0.81829862],
#        [0.85068062],
#        [0.85268463],
#        [0.02136691],
#        [0.16098635],
#        [0.01680261],
#        [0.60803525],
#        [0.78249666],
#        [0.81392537],
#        [0.83443034],
#        [0.09744949],
#        [0.23797182],
#        [0.06367701],
#        [0.83887719],
#        [0.85809792],
#        [0.78916436],
#        [0.08772677],
#        [0.01653281],
#        [0.80017765],
#        [0.84627456],
#        [0.68511368],
#        [0.80670363],
#        [0.04757525],
#        [0.81536081],
#        [0.01463301],
#        [0.75309558],
#        [0.02270158]])

# %%
ypr[ypr>0.5]=1
ypr[ypr<=0.5]=0
plt.scatter(X[:,0], X[:,1], c=ypr)
